# %%
import pandas as pd
import numpy as np

import requests

from io import StringIO

# %% [markdown]
# # Our task is to find insights & realtion ships using plots

# %% [markdown]
# ## Flight number & Payload mass

# %%
sns.catplot(x = "FlightNumber" , y = "PayloadMass" ,hue = "Class",data = df, aspect =5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %% [markdown]
# ##  Flight number & Launch site

# %%
sns.catplot(data = df, x = "FlightNumber", y = "LaunchSite", hue = "Class", aspect = 5)

plt.xlabel("Flight Number" , fontsize = 20)
plt.ylabel("Site" , fontsize = 20)
plt.show()

# %% [markdown]
# ### The above plot shows that differnt sites have differnt sucess rate , which is the class column.

# %%
sns.catplot(data = df, x = "PayloadMass" , y = "LaunchSite", aspect = 3, hue = "Class" )

# %%
sns.catplot(data = df, x = "Class" , y = "PayloadMass" , kind = "box", aspect = 3, hue = "LaunchSite") 
print("s")
# Out:
# s

# %% [markdown]
# ### This plot actully shows that launches at  KSC LC 39A site have a higher success rate compared to the other sites

# %% [markdown]
# ### Lets to investiagte why a few launches at this site still did not suceed

# %%
df[(df["Class"]== 0)& (df["LaunchSite"] =="KSC LC 39A") ]
# Out:
#     FlightNumber        Date BoosterVersion   PayloadMass Orbit  LaunchSite  \
# 27            28  2017-03-16       Falcon 9   5600.000000   GTO  KSC LC 39A
# 30            31  2017-05-15       Falcon 9   6070.000000   GTO  KSC LC 39A
# 34            35  2017-07-05       Falcon 9   6761.000000   GTO  KSC LC 39A
# 72            73  2020-01-19       Falcon 9   6104.959412    SO  KSC LC 39A
# 76            77  2020-03-18       Falcon 9  15600.000000  VLEO  KSC LC 39A
#
#        Outcome  Flights  GridFins  Reused   Legs                LandingPad  \
# 27   None None        1     False   False  False                       NaN
# 30   None None        1     False   False  False                       NaN
# 34   None None        1     False   False  False                       NaN
# 72   None None        4     False    True  False                       NaN
# 76  False ASDS        5      True    True   True  5e9e3032383ecb6bb234e7ca
#
# ...

# %%
df[(df["Class"]== 1)& (df["LaunchSite"] =="KSC LC 39A") ]["GridFins"]
# Out:
# 26    True
# 28    True
# 29    True
# 31    True
# 32    True
# 35    True
# 37    True
# 39    True
# 40    True
# 49    True
# 57    True
# 62    True
# 77    True
# 78    True
# 85    True
# 86    True
# 87    True
# Name: GridFins, dtype: bool

# %% [markdown]
# ### It is very intersting to note that the launches that did not succeeded at KSC LC 39A were not equiped with grid fins. While all the launches that succeeded at the same site had been equiped with grid fins

# %% [markdown]
# ### To sum up, we can safely say that all launhces at the site of KSC LC 39A  with GridFins had a sucess rate of 100 %. This implies that KSC LC 39A should be the main laucnh site for SPACEX and all launhces should be equiped with grid fins.

# %% [markdown]
# ### Additionaly, the Payload mass is faily corrlated with the sucess rate of the mission. This implies that increasing the mass can be benfical.
